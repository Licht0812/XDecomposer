# %% [markdown]
# **Figure 1 - Default Settings**: Describe how the XRD pattern is simulated with default settings in Pysimxrd. The real factors that are considered in this simulation.
#
# **Figure 2 - Prefect Orientation**: Show the simulation results with an increased level of prefect orientation.
#
# **Figure 3 - Thermo Vibration**: Show how thermal vibrations can broaden peaks.

# %%
from Pysimxrd import generator
from ase.db import connect

# choosing crystal (id=8) for an illustration
database = connect('demo_mp.db')
entry_id = 8

# %%
pip show pysimxrd

# %%
import matplotlib.pyplot as plt

x, y = generator.parser(database, entry_id)

plt.figure(figsize=(8, 6))
plt.plot(x, y, color='royalblue', linewidth=2.5)

plt.xlabel('2θ (degrees)', fontsize=14, weight='bold')
plt.ylabel('Intensity (a.u.)', fontsize=14, weight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()  #

plt.savefig('./xrd_pattern1.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

x, y = generator.parser(database, entry_id, prefect_orientation=[0.2,0.2])

plt.figure(figsize=(8, 6))
plt.plot(x, y, color='royalblue', linewidth=2.5)

plt.xlabel('2θ (degrees)', fontsize=14, weight='bold')
plt.ylabel('Intensity (a.u.)', fontsize=14, weight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()  #

plt.savefig('./xrd_pattern2.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

x, y = generator.parser(database, entry_id, thermo_vibration=0.4,grainsize=5)

plt.figure(figsize=(8, 6))
plt.plot(x, y, color='royalblue', linewidth=2.5)

plt.xlabel('2θ (degrees)', fontsize=14, weight='bold')
plt.ylabel('Intensity (a.u.)', fontsize=14, weight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()  #

plt.savefig('./xrd_pattern3.png', dpi=300)
plt.show()
